# %% [markdown]
# # **Data Visualization Report**
#
# ### **Title**: `Exploring Iris Dataset: Visualizing Species Differentiation`
#
# `Professor:`
# Dr. Hao Yanbin
#
# ## Introduction:
# This Python script is designed for data visualization using the Iris dataset. The Iris dataset comprises 150 rows of data, each representing an Iris flower, and includes measurements of four attributes: sepal length, sepal width, petal length, and petal width, all in centimeters. The dataset contains three species of Iris flowers: Setosa, Virginica, and Versicolor, with 50 samples for each species.
#
# The purpose of the script is to visualize the data to understand its nature and identify any patterns or insights it may contain. Data visualization allows us to explore the distribution of data, relationships between variables, and correlations among them.
#
# To accomplish this task, the script imports several libraries:
#
# - numpy (abbreviated as np): A library for numerical computations.
# - pandas (abbreviated as pd): A library for data manipulation and analysis, particularly useful for handling tabular data like CSV files.
# - seaborn (abbreviated as sns): A library for statistical data visualization, which provides a high-level interface for drawing attractive and informative statistical graphics.
# - matplotlib.pyplot (imported as plt): A plotting library that provides a MATLAB-like interface for creating visualizations.
#
# Through a series of visualizations including `histograms`, `scatter plots`，`box plots`, `violin plots`, and `linear regression`, I aim to explore the characteristics unique to each species of Iris flower.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### **`1`**
# I began by loading the Iris dataset from a CSV file named iris.csv into a DataFrame called iris using the `pd.read_csv()` function. This function reads the CSV file and converts it into a DataFrame, which is a tabular data structure provided by the Pandas library.
#
# Later, the script prints the first few rows of the dataset using the `head()` method to verify that the data has been loaded correctly and to inspect its structure and contents. This step ensures that the dataset has been successfully imported and can be used for further analysis and visualization.

# %%
# Importing necessary libraries
import numpy as np  # Importing NumPy library for numerical operations
import pandas as pd  # Importing Pandas library for data manipulation and analysis
import seaborn as sns  # Importing Seaborn library for statistical data visualization
import matplotlib.pyplot as plt  # Importing Matplotlib library for plotting graphs

# Load the data from the CSV file
iris = pd.read_csv('iris.csv')  # Reading the iris dataset from the CSV file into a DataFrame called 'iris'

# Displaying the first few rows of the dataset to verify the data has been loaded correctly
print(iris.head())  # Printing the first few rows of the dataset to inspect the structure and contents
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### **`2`**
# Dataset Information:
# The iris dataset consists of 5 columns:
# - variety: The target or response column, representing the species of the iris flower, which I aim to predict based on other feature columns.
# - sepal.length: The sepal length for the iris flower in centimeters.
# - sepal.width: The sepal width for the iris flower in centimeters.
# - petal.length: The petal length for the iris flower in centimeters.
# - petal.width: The petal width for the iris flower in centimeters.

# %%
#Checking the column info
iris_info = iris.info()
iris_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### **`3`**
# The provided code computes descriptive statistics for the iris dataset and assigns the result to a variable named `iris_stats`. The `describe()` function in Pandas calculates summary statistics for numerical columns in the DataFrame, including count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile or Q2), 75th percentile (Q3), and maximum values.
#
# The variable `iris_stats` will contain a DataFrame with these summary statistics, making it easy to inspect the distribution and variability of numerical features in the iris dataset. This summary can provide insights into the central tendency, spread, and shape of the data distribution for each numerical attribute.

# %%
# Checking the statistics for the iris dataset
iris_stats = iris.describe()
iris_stats
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### **`4`**
# I then grouped the Iris dataset (iris) by the species of iris flower, assuming that the column containing the species information is named 'variety'. Then, it calculates the minimum values for each numerical attribute within each group (species). The resulting DataFrame (iris_min) will contain the minimum values for each numerical attribute (such as sepal length, sepal width, petal length, and petal width) for each species of iris flower.

# %%
# Grouping by species to find the minimum values
iris_min = iris.groupby('variety').min()
iris_min
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               4.3          2.3           1.0          0.1
# Versicolor           4.9          2.0           3.0          1.0
# Virginica            4.9          2.2           4.5          1.4

# %% [markdown]
# ### **`5`**
# I also grouped the Iris dataset (`iris`) by the species of iris flower, assuming that the column containing the species information is named `Species`. Then, it calculates the maximum values for each numerical attribute within each group (species). The resulting DataFrame (`iris_max`) will contain the maximum values for each numerical attribute (such as sepal length, sepal width, petal length, and petal width) for each species of iris flower.

# %%
# Grouping by species to find the maximum values
iris_max = iris.groupby('variety').max()
iris_max
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.8          4.4           1.9          0.6
# Versicolor           7.0          3.4           5.1          1.8
# Virginica            7.9          3.8           6.9          2.5

# %% [markdown]
# ### **`6`**
# The code checks for any null (missing) data in the Iris dataset (`iris`). It returns a boolean Series indicating whether each column contains null values (`True` if there are null values, `False` otherwise). This Series is assigned to the variable `iris_null`. Finally, it prints the result, showing whether there are any null values in each column of the Iris dataset.

# %%
# Checking if there is any null data in the iris dataset
iris_null = iris.isnull().any()
iris_null
# Out:
# sepal.length    False
# sepal.width     False
# petal.length    False
# petal.width     False
# variety         False
# dtype: bool

# %% [markdown]
# ### **`7`**
# The code groups the Iris dataset (`iris`) by the species of iris flower, assuming that the column containing the species information is named 'variety'. Then, it counts the number of samples for each species. The resulting DataFrame (`iris_count`) will contain the count of samples for each species of iris flower.

# %%
# Grouping by species to count the number of samples for each species
iris_count = iris.groupby('variety').count()
iris_count
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa                50           50            50           50
# Versicolor            50           50            50           50
# Virginica             50           50            50           50

# %% [markdown]
# # **1 `Histogram`**
# ## Visualization 1.1

# %% [markdown]
# Firstly. to examine the data's distribution, `Histograms` are utilized. They offer insights into whether the data follows a normal or skewed distribution pattern. When examining individual column distributions, providing only the specific column is sufficient.

# %%
# Using countplot to visualize the number of each kind of iris species flower
sns.countplot(x=iris['variety'])
plt.show()

# %% [markdown]
# To examine the entire DataFrame, I decided to pass the DataFrame itself.
# However, when dealing with a larger number of columns or when one specifically require the distribution for a particular column,
# It is advisable to analyze the histogram of each individual column separately.

# %% [markdown]
# ## Visualization 1.2

# %%
# Visualizing the distribution of data (Petal Length) using Histogram
iris['petal.length'].hist(bins=20)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Petal Length')
plt.show()

# %% [markdown]
# To examine the distribution of `petal length` and `petal width` across different species in the Iris Flower Dataset and enhance clarity through additional visual enhancements, the following approach can be adopted:

# %% [markdown]
# ## Visualization 1.3

# %%
# Visualizing the distribution of data for the entire dataset
iris.hist(bins=20, figsize=(10,10))
plt.suptitle('Histograms of Iris Dataset Features', fontsize=16)
plt.show()

# %% [markdown]
# ## Visualization 1.4
# **`Final Visualization 1`**

# %%
# Visualizing the distribution of Iris dataset features for different species
iris_subset = iris.groupby('variety')

# Plotting histograms for Petal Length, Petal Width, Sepal Length, and Sepal Width
plt.figure(figsize=(12, 10))

plt.suptitle('Distribution of Iris Dataset Features across 3 varieties', fontsize=20)  # Add this line for the overall subtitle

plt.subplot(221)
iris_subset['petal.length'].plot.hist(alpha=0.4)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Petal Length for different varieties')
plt.legend(loc=(0.69, 0.75))
plt.grid()

plt.subplot(222)
iris_subset['petal.width'].plot.hist(alpha=0.4)
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Petal Width for different varieties')
plt.legend(loc=(0.69, 0.75))
plt.grid()

plt.subplot(223)
iris_subset['sepal.length'].plot.hist(alpha=0.4)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length for different varieties')
plt.legend(loc=(0.69, 0.75))
plt.grid()

plt.subplot(224)
iris_subset['sepal.width'].plot.hist(alpha=0.4)
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width for different varieties')
plt.legend(loc=(0.69, 0.75))
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# # **2 `Scatter Plots`**
# ## Visualization 2.1

# %% [markdown]
# Next, one can explore the connections between features by employing scatter plots. We have the option to examine individual scatterplots for various variables or utilize Seaborn's Pairplot to assess the relationships of multiple variables concurrently. However, it's not recommended to employ Pairplot when dealing with a large number of features. In such instances, it's preferable to use a subset of features for the Pairplot visualization.

# %%
# Exploring connections between features using scatter plots
sns.set_style('darkgrid')

plt.figure(figsize=(10, 10))
plt.subplot(211)
sns.scatterplot(data=iris, x='petal.length', y='petal.width', hue='variety')
plt.title('Relationship between Petal Length and Petal Width', fontsize=20)

plt.subplot(212)
sns.scatterplot(data=iris, x='sepal.length', y='sepal.width', hue='variety')
plt.title('Relationship between Petal Length and Sepal Length', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# Given the relatively small size of this dataset and its inclusion of only four features, employing a pairplot allows us to examine the relationship between two variables categorized by the Species column.

# %% [markdown]
# ## Visualization 2.2
# **`Final Visualization 2`**

# %%
# Using Pairplot to analyze relationships between features
sns.pairplot(data=iris, hue='variety')
plt.suptitle('Pairplot of Iris Dataset Features by Variety', fontsize=10, ha='center', va='bottom')
plt.show()

# %% [markdown]
# # **3 `Box Plots`**
# ## Visualization 3.1

# %% [markdown]
# `Box plots` serve as an alternative method for visualizing distributions, offering a more comprehensive overview compared to `histograms`. They showcase various statistical measures such as the minimum value, maximum value, first and third quartiles, median, interquartile range (IQR), and identification of outliers. Additionally, box plots are beneficial when exploring distributions alongside categorical variables.

# %%
# Visualizing the distribution of Sepal Length for the Versicolor variety using box plots
plt.figure(figsize=(8, 6))
sns.boxplot(data=iris, y='sepal.length')
plt.title('Boxplot of Sepal Length for Versicolor Variety', fontsize=16)
plt.xlabel('Versicolor Variety', fontsize=12)
plt.ylabel('Sepal Length (cm)', fontsize=12)
plt.show()

# %% [markdown]
# ## Visualization 3.2
# **`Final Visualization 3`**

# %%
# Plotting histograms for Petal Length, Petal Width, Sepal Length, and Sepal Width
plt.figure(figsize=(12, 10))

plt.suptitle('Comparing the distribution of Iris dataset features for different species using box plots', fontsize=20)  # Add this line for the overall subtitle


# Boxplot of Sepal Length by Species
plt.subplot(221)
sns.boxplot(data=iris, x='variety', y='sepal.length', hue='variety')
plt.title('Boxplot of Sepal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Sepal Length (cm)', fontsize=12)

# Boxplot of Sepal Width by Species
plt.subplot(222)
sns.boxplot(data=iris, x='variety', y='sepal.width', hue='variety')
plt.title('Boxplot of Sepal Width by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Sepal Width (cm)', fontsize=12)

# Boxplot of Petal Length by Species
plt.subplot(223)
sns.boxplot(data=iris, x='variety', y='petal.length', hue='variety')
plt.title('Boxplot of Petal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Length (cm)', fontsize=12)

# Boxplot of Petal Width by Species
plt.subplot(224)
sns.boxplot(data=iris, x='variety', y='petal.width', hue='variety')
plt.title('Boxplot of Petal Width by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Width (cm)', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **4 `Violin Plots`**
# ## Visualization 4.1

# %% [markdown]
# It's worth noting that Violin Plots share similarities with Box Plots in terms of visualizing distributions.

# %%
# Visualizing the distribution of Sepal Length for the Versicolor variety using box plots
plt.figure(figsize=(8, 6))
sns.violinplot(data=iris, y='sepal.length')
plt.title('Boxplot of Sepal Length for Versicolor Variety', fontsize=16)
plt.xlabel('Versicolor Variety', fontsize=12)
plt.ylabel('Sepal Length (cm)', fontsize=12)
plt.show()

# %% [markdown]
# ## Visualization 4.2
# **`Final Visualization 4`**

# %%
# Plotting histograms for Petal Length, Petal Width, Sepal Length, and Sepal Width
plt.figure(figsize=(12, 10))

plt.suptitle('Comparing the distribution of Iris dataset features for different species using violin plots', fontsize=20)  # Add this line for the overall subtitle


# Boxplot of Sepal Length by Species
plt.subplot(221)
sns.violinplot(data=iris, x='variety', y='sepal.length', hue='variety')
plt.title('Violinplot of Sepal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Sepal Length (cm)', fontsize=12)

# Boxplot of Sepal Width by Species
plt.subplot(222)
sns.violinplot(data=iris, x='variety', y='sepal.width', hue='variety')
plt.title('Violinplot of Sepal Width by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Sepal Width (cm)', fontsize=12)

# Boxplot of Petal Length by Species
plt.subplot(223)
sns.violinplot(data=iris, x='variety', y='petal.length', hue='variety')
plt.title('Violinplot of Petal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Length (cm)', fontsize=12)

# Boxplot of Petal Width by Species
plt.subplot(224)
sns.violinplot(data=iris, x='variety', y='petal.width', hue='variety')
plt.title('Violinplot of Petal Width by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Width (cm)', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **5 `Linear Regression`**
# ## Final Visualization 5

# %% [markdown]
# The provided code segment conducts `linear regression` analysis based on the features of the Iris dataset.

# %%
# Linear regression based on sepal
g = sns.lmplot(x="sepal.width", y="sepal.length", hue="variety", data=iris)
plt.title('Linear Regression based on Sepal', fontsize=16)

# Linear regression based on petal
g = sns.lmplot(x="petal.width", y="petal.length", hue="variety", data=iris)
plt.title('Linear Regression based on Petal', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Linear Regression based on Petal')

# %% [markdown]
# # **6 `Conclusion`**
#
# In this data visualization report, I explored the Iris dataset to understand the characteristics unique to each species of Iris flower. Through various visualization techniques including histograms, scatter plots, box plots, violin plots, and linear regression, one can gain insights into the distribution of data, relationships between variables, and variations among different species.
#
# From the `histograms`, I observed the distributions of individual features and their variations across different species. `Scatter plots` allowed me to visualize relationships between pairs of variables, discerning patterns and clusters that differentiate species. `Box plots` and `violin plots` provided a comprehensive view of the distribution of features, highlighting differences and similarities among species.
#
# Additionally, `linear regression` analysis allowed me to explore the linear relationship between certain features, providing insights into how they may vary together within each species.
#
# Overall, these visualizations provided a deeper understanding of the Iris dataset and facilitated the identification of distinguishing characteristics among the Setosa, Virginica, and Versicolor species. Such insights are valuable for further analysis and classification tasks in data science and machine learning applications.
